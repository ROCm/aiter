# %% [markdown]
# # MI300X Roofline Analysis – MoE Kernels
#
# This notebook presents **one single interactive roofline plot** for all kernels.
# Use the dropdown widgets (colour, size, filter-by) to explore the data.

# %%
# Import the helper and display the plot
from roofline_plot import show_roofline

show_roofline("kernels_with_counters_filtered.csv")

# %% [markdown]
# ## Export Interactive Plot as HTML
#
# Creates a standalone HTML file with Y-axis toggle dropdown.
#
# **HTML Features:**
# - ✓ Y-axis toggle (MFMA actual / theoretical)
# - ✓ Full zoom, pan, hover tooltips
# - ✓ Click legend items to show/hide traces
# - ℹ️ For full filter/color dropdowns, use Jupyter notebook above
#
# **Default View:** Color by kernel_type, Y = MFMA actual

# %%
# Export standalone HTML with Y-axis toggle
from roofline_plot import create_standalone_html

fig = create_standalone_html(
    csv_path="kernels_with_counters_filtered.csv",
    output_file="roofline_interactive.html"
)
